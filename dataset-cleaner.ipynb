# %%
import pandas as pd

# %%
df=pd.read_csv("/home/avinsah/Desktop/final year project/dataset/IIM Shillong.csv")

# %%
df
# Out:
#                  Result Number                                 Author  \
# 0     1 26326030000 (i) on (i)  Upadhyay, Parijat  Upadhyaya, Parijat
# 1                          NaN                        View last title
# 2                          NaN                                    NaN
# 3     2 22433590700 (i) on (i)                    Roychoudhury, Basav
# 4                          NaN                        View last title
# ..                         ...                                    ...
# 208                        NaN                        View last title
# 209                        NaN                                    NaN
# 210  71 57190121848 (i) on (i)                          Shukla, Neeti
# 211                        NaN                        View last title
# 212                        NaN                                    NaN
#
#      Documents  \
# 0         34.0
# 1          NaN
# 2          NaN
# 3         24.0
# 4          NaN
# ..         ...
# ...

# %%
df.drop(['Result Number'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                                   Author  Documents  \
# 0  Upadhyay, Parijat  Upadhyaya, Parijat       34.0
# 1                    Roychoudhury, Basav       24.0
# 2                           Joshi, Rohit       20.0
# 3                     Pattusamy, Murugan       18.0
# 4      Choudhary, Kailash  Choudhary, K.       17.0
#
#    h-index          Author metrics Scopus is adding an array of metrics for researchers. As an initial step, the h-index has been added.  The h-graph is one way of displaying and comparing the productivity and impact of published work of scholars. It should only be used together with a mix of quantitative and qualitative metrics.  More metrics will be added in the course of the year.  \
# 0                                               11.0
# 1                                                7.0
# 2                                                7.0
# 3                                                7.0
# 4                                                9.0
#
# ...

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#                                   Author  Documents  \
# 0  Upadhyay, Parijat  Upadhyaya, Parijat       34.0
# 1                    Roychoudhury, Basav       24.0
# 2                           Joshi, Rohit       20.0
# 3                     Pattusamy, Murugan       18.0
# 4      Choudhary, Kailash  Choudhary, K.       17.0
#
#    h-index          Author metrics Scopus is adding an array of metrics for researchers. As an initial step, the h-index has been added.  The h-graph is one way of displaying and comparing the productivity and impact of published work of scholars. It should only be used together with a mix of quantitative and qualitative metrics.  More metrics will be added in the course of the year.  \
# 0                                               11.0
# 1                                                7.0
# 2                                                7.0
# 3                                                7.0
# 4                                                9.0
#
# ...

# %%
df.reset_index(inplace = True, drop = True)

# %%
df.rename(columns={df.columns[2]:"h-index"},inplace=True)

# %%
df.head()
# Out:
#                                   Author  Documents  h-index  \
# 0  Upadhyay, Parijat  Upadhyaya, Parijat       34.0     11.0
# 1                    Roychoudhury, Basav       24.0      7.0
# 2                           Joshi, Rohit       20.0      7.0
# 3                     Pattusamy, Murugan       18.0      7.0
# 4      Choudhary, Kailash  Choudhary, K.       17.0      9.0
#
#                                Affiliation      City Country/Territory
# 0  Indian Institute of Management Shillong  Shillong             India
# 1  Indian Institute of Management Shillong  Shillong             India
# 2  Indian Institute of Management Shillong  Shillong             India
# 3  Indian Institute of Management Shillong  Shillong             India
# 4  Indian Institute of Management Shillong  Shillong             India

# %%
name=df.iloc[0][3]
df.to_csv(f'/home/avinsah/Desktop/final year project/cleaned datasets/{name}.csv')
